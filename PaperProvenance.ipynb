# %% [markdown]
# # Graphing the Provenance of a Paper
#
# I want to visually represent the history of a field leading up to a given paper.
#
# I think a cool way to do this would be as a force-directed graph (in which the connections between nodes are springs in a physics simulation) where the x axis of nodes (that is, papers) is fixed to a timeline.
#
# The first order of business: get the data from the SemanticScholar API.

# %%
import numpy as np
import pandas as pd
import requests
from datetime import datetime

# %%
def get_provenance(seed_paper):
    """Given seed paper, generate nodes (dict) and edge list (dataframe) for its parents and grandparents"""
    nodes = dict()
    # Get metadata and references of seed paper
    http = requests.get("https://api.semanticscholar.org/graph/v1/paper/%s?fields=title,year,publicationDate,journal,authors,references.title,references.publicationDate,references.year,references.journal,references.authors" %seed_paper)
    if http.status_code == 429:
        print("Waiting 5 Minutes for access to the API...")
        time.sleep(300)
        http = requests.get("https://api.semanticscholar.org/graph/v1/paper/%s?fields=title,year,publicationDate,journal,authors,references.title,references.publicationDate,references.year,references.journal,references.authors" %seed_paper)
    json = http.json()
    # Put seed paper metadata into nodes dict
    nodes[json['paperId']] = [json['title'], datetime.strptime(json['publicationDate'], '%Y-%m-%d'), json['year'], json['journal'], json['authors']]
    # Put corpus-listed references into nodes dict
    references_df = pd.DataFrame(json['references']).dropna()
    for index, row in references_df.iterrows():
        nodes[row['paperId']] = [row['title'], datetime.strptime(row['publicationDate'], '%Y-%m-%d'), row['year'], row['journal'], row['authors']]
    # Make edges list with corpus-listed references
    edges = pd.DataFrame({"referencing": [json['paperId']]*len(references_df),
                          "referenced": references_df['paperId']})
    # For each reference, get its references and their metadata, and add them to the dicts
    for index, row in references_df.iterrows():
        # Get metadata and references of referenced paper
        temp_http = requests.get("https://api.semanticscholar.org/graph/v1/paper/%s?fields=title,year,publicationDate,journal,authors,references.title,references.publicationDate,references.year,references.journal,references.authors" %row['paperId'])
        if temp_http.status_code == 429:
            print("Waiting 5 Minutes for access to the SemanticScholar API...")
            time.sleep(300)
            temp_http = requests.get("https://api.semanticscholar.org/graph/v1/paper/%s?fields=title,year,publicationDate,journal,authors,references.title,references.publicationDate,references.year,references.journal,references.authors" %row['paperId'])
        if temp_http.status_code == 404:
            continue
        temp_json = temp_http.json()
        ## no need to put referenced paper metadata into nodes dict
        # Put corpus-listed reference references into nodes dict
        temp_references_df = pd.DataFrame(temp_json['references']).dropna()
        if len(temp_references_df) == 0:
            continue
        for i, r in temp_references_df.iterrows():
            nodes[r['paperId']] = [r['title'], datetime.strptime(r['publicationDate'], '%Y-%m-%d'), r['year'], r['journal'], r['authors']]
        # Make edges list with corpus-listed reference references, and append to main edge list
        temp_edges = pd.DataFrame({"referencing": [temp_json['paperId']]*len(temp_references_df),
                                   "referenced": temp_references_df['paperId']})
        edges = pd.concat([edges, temp_edges])
        json[row['paperId']] = temp_json
    edges = edges.set_index("referencing").reset_index()
    # # Drop self references
    # loops = 0
    # for index, row in edges.iterrows():
    #     if not ((row['referencing'] in nodes) and (row['referenced'] in nodes) and (row['referencing'] != row['referenced'])):
    #         edges = edges.drop(index = index)
    #         loops += 1
    # print(loops, 'self references or unindexed nodes dropped from edge list')
    return nodes, edges

# %% [markdown]
# Now I'll use my function to get the provenance of my paper of choice!

# %%
nodes, edges = get_provenance('10.5334/joc.257')

# %%
# list of direct references
direct_refs = list(edges.iloc[:,1][edges['referencing'] == edges.iloc[0,0]])

# filter out grandparent papers that were only referenced once or twice (otherwise the graph will be really cluttered)
referenced_enough = edges.iloc[:,1].value_counts() > 2
referenced_enough = referenced_enough[referenced_enough].to_dict()
for index, row in edges.iterrows():
    if ((row['referenced'] not in referenced_enough) and (row['referenced'] not in direct_refs)):
        print("Dropped referenced: "+row['referenced'])
        edges = edges.drop(index)
# Out:
# Dropped referenced: aedad0c48f45ad9b8ed0ededa752e164bacddb0c
# Dropped referenced: 038b4c5e2fc06f06058905342a832ab4d09edb8b
# Dropped referenced: 03cbfd8cea1b11fdbc7f6bbac0859520b1f71ee3
# Dropped referenced: 7c324b84e37987d1da71e0a75e9519c9f946ec5e
# Dropped referenced: 45c783115f49045250185056a6684f23fc3afe72
# Dropped referenced: ca80892f2e5c05f894b6663010752540bab5f22b
# Dropped referenced: 87a775279bdd43847ca692d4258e306052250088
# Dropped referenced: 4a0709039e83440e3e792de640712f552da1279a
# Dropped referenced: d1e0d17f6b9ddd86ce480682339c41afb5e2bfdf
# Dropped referenced: 2309e509e82bf9dba72f1208ba2b81116e0d87db
# Dropped referenced: ccb47b50c280bbec3fe841dcf4476d905bf2241e
# Dropped referenced: 54c35a6b1b87c631cb76ba2d8a762df888f4d442
# Dropped referenced: 4a529dd70012b8527ab8da53f2e4a1d8b9dd7da3
# Dropped referenced: fcef282918801d04e2d2a2fba3804f19942fb6a3
# Dropped referenced: 0e60bcfd05f7ac3f2d55bb78183bd2e3e2ee4bd8
# Dropped referenced: ca0d27a1ecb3976cf57256af91d7543b2b3b61a5
# Dropped referenced: baaa6a4551d069185d1a537fa23387eea24e0fd8
# Dropped referenced: 3ec198a8e383f9e0541ace670452dee52f1eb1d3
# Dropped referenced: 16e6ba54276937f7fe77700dbf279e6055c8a9d4
# Dropped referenced: 26d7f0292b373f2c479f5b4766c35be62514e507
# Dropped referenced: b21ea6ed237662777fe98b8e55aaf1205a602a6f
# Dropped referenced: 72bc8f3fd18cc190fa51c97e6ba4a39cf461be76
# Dropped referenced: 9b536c7b0f45d4b512f337d0acda09ca3e4cd953
# Dropped referenced: 671ce1371c5452bf72f4542d5d7526cadb0860b1
# Dropped referenced: f760de4a8849eda8a71272b96dafc63f8a2e34ba
# Dropped referenced: 7c1e5c788c4fd8c5a17118ac300a05bc93a96f94
# Dropped referenced: 3576d450602f12b51ed14d83ec1e85eab804ce68
# Dropped referenced: 5443ed9adb8c0319a82a36cb8e00feb1a6c6be76
# Dropped referenced: 5b226983d0800611181d84aefc8e10541ac6c39d
# Dropped referenced: 028916e62ddc516ff4e64fb0eb1e058eded48fcb
# Dropped referenced: c0a7be6c58321e9124734e9c1be9dc350fd03bc0
# Dropped referenced: 5cfc3c26ee547b96c25aa4b2c3905e634fd73d6c
# Dropped referenced: 7ad8fb4a8af5e4a22b6bd40df055f8a3e0ec69dd
# Dropped referenced: 1f128f91e2a994efda89157ac7ce8b42306cc102
# Dropped referenced: 72ca247651dcac6e9a425c212dba5e50d5670ddd
# Dropped referenced: e31606c0cdb2b2cf1a8c749dd71402053b8f2b12
# Dropped referenced: 48138c7b9464f5111b56f11d028fd049f696e9cc
# Dropped referenced: 0aea189abfc1502ca924bcf77b7ac3d7619df5e9
# Dropped referenced: 001c07aefcc186013184009e0c83847f28867e08
# Dropped referenced: 63cfe5110955dc6542c6f0079b9c25f69fa3016f
# Dropped referenced: 270bf58fc9cf1b83cc5c243cf11df4e6e69c2dca
# Dropped referenced: 20aeb2357e9e215787c7e0d0acfe7a6b598c9103
# Dropped referenced: 1dcf064e7b6389f18aa0d0d9b7660b3ea5bbbe01
# Dropped referenced: d4236c86ee383e3aeade5f3cfc9e924e2514e400
# Dropped referenced: 7200ff3d863fcb7e92faef37f7cd133673069ecb
# Dropped referenced: 90cc2b77c37b857770996e6b3a96b8f46ef41716
# Dropped referenced: 34c6405fd95cabd6fc05c2db6ef5db2475d6b41f
# Dropped referenced: dce7a44505c47dc2396f232a890cac602b950056
# Dropped referenced: c131291246e8f548172827af1303d3fdca1f3d57
# Dropped referenced: 03cbb25a05e7d36831fb0cef777c0e5e5555030c
# Dropped referenced: 1ec3c533e569ff3bd8b2935df7eafb661a1ea5de
# Dropped referenced: deb990a44d97b9474e6a076537e375f8cb9e1a06
# Dropped referenced: 40c8e0b1a8202071dca966674d3d55f3fb3f202c
# Dropped referenced: f38554089c57664766d765576b6034e162a7c8c0
# Dropped referenced: 925e9bc07af33345b6c3ab807abd3fb5a9925836
# Dropped referenced: fbde03014ca75a2f7bbd67983e7e4c7f952dde1b
# Dropped referenced: 2415fd343caa11d949e9be8b78f0e010625c0706
# Dropped referenced: 620dc9d02c531c12746c0423249954e5b19c3481
# Dropped referenced: 1319bf6218cbcd85ac7512991447ecd9d776577d
# Dropped referenced: ca18d52ad06fe8df8a07ef5619746a310c2cacf7
# Dropped referenced: 950ad9347e99283de9638a51ac28b5e66e5aa106
# Dropped referenced: a1884b35e9f250cb4e57c16ed58c1389420aaf8c
# Dropped referenced: 6e820cf11712b9041bb625634612a535476f0960
# Dropped referenced: f6244b765b42fea92aa0f14ffecaec77d6bb1ac4
# Dropped referenced: a7f2d286a9b544bf48dc63b539a13b2853839184
# Dropped referenced: e1409d20538576e7a38e2830f17e6d8970cec2dc
# Dropped referenced: 5d668c938b5b7ed091e55a69e7483005da909877
# Dropped referenced: ead5d9784d84bfe2d0dede0ca48029eca2fd0bc3
# Dropped referenced: bf3ea67d6c3015d4409200e65e1fe6b01a9265a5
# Dropped referenced: b4760c6ce56ddda88927812cf0cea3964331b718
# Dropped referenced: 421d66f24a27f2ab88763e763ce3697eabcd98f8
# Dropped referenced: 9c570ea4b16fbda5029aab4cc972f2ebe4f30d2f
# Dropped referenced: 4bf0e9786d6638dc7d4b1fc929def68da9003c4e
# Dropped referenced: 9a3494659659438761a54cb2bb2bb462b8b53bc6
# Dropped referenced: 97d9b9119bffc8b3bdd8859f88c52ead021a1b27
# Dropped referenced: 755e6ac5b18c5ffc69398f94685d10373a039ec9
# Dropped referenced: a5bd573f2786589b85026c347b1cc7313164731c
# Dropped referenced: a991d1b487a2dae9f54ffb08aa70d258ce85ce84
# Dropped referenced: ac5ca8ed062c57c01001a28e33f3aa022a917ec9
# Dropped referenced: 1ef9d441b0df554d730bd6a92047eeb9a2caf92c
# Dropped referenced: 9349f692e9fd870a06c552361b6e8831fc097a3c
# Dropped referenced: 08e65f308e04a15a73e747a979541454611617c6
# Dropped referenced: c05937cd20abc68a2ac112923a96632dc3b917fc
# Dropped referenced: 0a4697f5a1ebb99ce265f2ea6c53a5029edab5be
# Dropped referenced: e6e180b36fdbd4569ac9e5b399f01de03a6d65ec
# Dropped referenced: a05a35fb4dd27273e1905abb0c9054dcbbc16090
# Dropped referenced: afd4e0139f433471d4eb3da59a503af81880d2a7
# Dropped referenced: 83b1fefacbc0d74e8bd0f1f3c86aebcadcabc2a1
# Dropped referenced: c63aad1d024de6d222baddbbc9f1b670388270cf
# Dropped referenced: a01f9de742d29b588473e6807e2bcbe93df59548
# Dropped referenced: 611c73225e8c0bd88d66e9c2d2ca066b7eee6cd3
# Dropped referenced: 7968b4947500c2df2c26da33d82e3e84d43288fd
# Dropped referenced: cd98856a72c0a41139bccb84db05c9b2a6c1bd67
# Dropped referenced: 812cb1722245dfc5f738bef41ef9c3acaff611ec
# Dropped referenced: a57a940868816d6a67a1536ee6d57493f8cb6a3e
# Dropped referenced: a5919031e0ae840b75453e2fe51cbcc94833e29b
# Dropped referenced: 7c9fef757216649b3b0a61c11b0dfcf2c89beab9
# Dropped referenced: e3f061c169fbbb51cbe8d280e8780f17dd02f2d5
# Dropped referenced: be9a26d161d88c792b6313618a57e4802e564c71
# Dropped referenced: 048cc53ccfc7df2a33969e7efa1d8c157aff1e3f
# Dropped referenced: 171fb58a000a2fcf176c47e00ce59cb9c531397a
# Dropped referenced: fe57732eaf3f757c221937b5e9bcda93d76d5d6f
# Dropped referenced: 7e07d99521053a210897153ef4c4cf36f9fadefc
# Dropped referenced: bb9a6aa67d0cd2fbdbfaea95d3e4ba92db0275a9
# Dropped referenced: 93bc678116f0a062de7f694e0552f56df924d08f
# Dropped referenced: 94abbf2b506b5eb5304c69af65cb8791f142de5b
# Dropped referenced: 38454e5b8fa349420ba9230d4de301b42c6f4265
# Dropped referenced: d4d4aafaaf95b40647885d27c866c083928457c0
# Dropped referenced: cd79af5b894cb4e845fc48ec7330f9b9ecd692ef
# Dropped referenced: 8ad0b9c4992a944a66b6562df511272b036762eb
# Dropped referenced: 0f2cd030fda4bb5a613c5d995b71f7080ec0923d
# Dropped referenced: 496a2a5eda9609cb0f4cf9c25eb647a6487f4985
# Dropped referenced: c2bc880156c10fc8d1752cd3d528e4ef96cbaac4
# Dropped referenced: 945ef00f813d64461df1141846485bbd37646e3b
# Dropped referenced: 191f75a9023ade43c810d7a24a576e4fcf0f0148
# Dropped referenced: 675b0c5150c3c439ad1056e8486cb2604963a9b9
# Dropped referenced: ad4d96e7366629555923dba073130082420781c6
# Dropped referenced: 39cc230f0b9905d77ba513b453eaaa8a0172041c
# Dropped referenced: 85798b2e922d715d2dcc5d84e49a6f8861777abc
# Dropped referenced: 9ab282969be51a92c73ca37d5c31a1ce4c6701f8
# Dropped referenced: d8c25e60013ee9b59cf54a1d0e5c1bbd8face43a
# Dropped referenced: c98386ddf2fe4973da42187a9e3c9167095acf4e
# Dropped referenced: cfdd870278e587c0a5469b64458351fbdbbe04b1
# Dropped referenced: 474d7e1ea3b5b64103a7918d25b855555a748a47
# Dropped referenced: 9bd38b75d75ea35a720b7647a93e8f5526348be6
# Dropped referenced: 8a9e43ee7d8c7cc3b77a54e2d691ebc600a42e65
# Dropped referenced: 6ca047eb75e8a41cff3e283877bf5d9fe8d59058
# Dropped referenced: c6646484cf19abd9eeed321ce5abc9574ff8ae11
# Dropped referenced: 03d61a33796234b8bae5ac38de9b26c1c5ed9e2f
# Dropped referenced: d9905137704d758689187f79b9f6c6acf41a1e57
# Dropped referenced: 93b8bffbbb500525b41cea3339907b5adef79045
# Dropped referenced: e24f3127e6df88c311478bd53cb766ef250ba523
# Dropped referenced: a4f08d285a7ea049e78564a4ca06c5403af4bea8
# Dropped referenced: d65ff869293ba3fe5f9e460656c657417e2f660b
# Dropped referenced: 911453d8560c8b50f75528c489da8263b6fa9c9c
# Dropped referenced: 2027b348305785f9005527d4b2bf5a93b631f1b9
# Dropped referenced: 09c30074930af2debda418e2f5f7c91a8fce3eab
# Dropped referenced: 139245a59338ffb1e9b281874a393cfbc2276627
# Dropped referenced: 57c82a005ae353f4683938b15a52e1b0561f6e43
# Dropped referenced: 0860461044d732f0f592ebbab188c2d637da4cf4
# Dropped referenced: 6d5a78967740db3b95265960c262569d5cfac27b
# Dropped referenced: f8fd19704aec93d861c92030f4a84cfe3b46825f
# Dropped referenced: 95e03c87840603f15870861d7400c4ccc81f9446
# Dropped referenced: 6b598e53ad5666659531f443287011b1b128275a
# Dropped referenced: 8a2fa093d26ac42002900ae0accfb6b7733add71
# Dropped referenced: 489c7727540dfc9fa51db05da42aa08bfb6451d3
# Dropped referenced: 20aeb2357e9e215787c7e0d0acfe7a6b598c9103
# Dropped referenced: 9eb8499c38a439d08b1640765fe3687fcb0aa0d3
# Dropped referenced: fd495d6cf7c3169bc58550fdf32be6e16e2800f8
# Dropped referenced: b413050d33fb2b819d12d7edc36cc900aeb7c12b
# Dropped referenced: 0dd277f355af369df1d653a04970c2a26ed677df
# Dropped referenced: 10cee025ec04a607c9b52102cc65b9569dfc02e1
# Dropped referenced: 68b18aedf7cb28030eecf45a5b81c2e27df40f0f
# Dropped referenced: 16d9a228765eda546bddce2f995212b3780c5b39
# Dropped referenced: bf3ea67d6c3015d4409200e65e1fe6b01a9265a5
# Dropped referenced: c767f7a2ad63250a96408a45e3f301006ec22b25
# Dropped referenced: 91406ec73942e5befb8ee0b2253952cec7f7232c
# Dropped referenced: 242a543a6f8c81af63dd389584aa3d875b0986b4
# Dropped referenced: b69a14fe9149a479b9c5363bcd17d755665e5f96
# Dropped referenced: 629d965d8f1972860a2cf3c05d5b37f46bde741c
# Dropped referenced: 1f222bf202b2f7d010d8a8c32fa0221b478c22a1
# Dropped referenced: cc837a3ba9791c94a87b9be533404face896292c
# Dropped referenced: d4f9c3811760c4c8635c92d9fe25d5273d17c3c1
# Dropped referenced: d876c0e6d19bf4e9e0c1e925460b3b48f832fc91
# Dropped referenced: 8fe75824e8814f041bf17517649b410057a2d848
# Dropped referenced: 048cc53ccfc7df2a33969e7efa1d8c157aff1e3f
# Dropped referenced: 1f28d35dddfd4dc60222eb9b53a9f61687f7fa47
# Dropped referenced: e4d29b18e9babff2daca7d967705d0a23abe16bd
# Dropped referenced: 04703fd1b7698277fbfbff5f177a1f58c0d2292f
# Dropped referenced: c867b3a4c0a36903cf6663faee00ed5df37f9e84
# Dropped referenced: ceb5b821cb0a6913009038df4176c7c3f5813fac
# Dropped referenced: 0f382d48991c9b3fef9f861c79ba7fc7cc8dbcca
# Dropped referenced: e7638394a2bd285633949ab25a6c384c857d9175
# Dropped referenced: f5759fa8a92713273fd9d7e3220a86a51ec47412
# Dropped referenced: 31cacb87e8cfbfe2507b593e1e9edd25d21c8b72
# Dropped referenced: da80afb7e7eff0b316b9237cdb8e80956e57e7f1
# Dropped referenced: 4235b53e3d7ddbd9281dfc17b4e50fe58060ccfb
# Dropped referenced: 9f21a6070b69f3bfe189b382ca75c2bbf3b8812f
# Dropped referenced: 0621dc65f4ad81e8d664ba88ab803f431bcc2548
# Dropped referenced: 9b6c9a5b78b81e88b83785e43bde158eed00eb77
# Dropped referenced: bef5dd2a35bc2d6d93650fccfb53e8ceacc512c4
# Dropped referenced: ff05fdf3fbd54b5e0f394a8a288bc9e26b2b3359
# Dropped referenced: c5d848285226bc286c61487e326e20cdeea5be19
# Dropped referenced: b76f42a2f17e070de66bf68d5b8b8a5277ba4512
# Dropped referenced: 532260e5a04bc0adb8a6c8e542db0de8fbe5dd98
# Dropped referenced: 863d2d65d74883565b891140aef6315a48955d5e
# Dropped referenced: ff8d3233458ff4269f42389d2bc7ba91f8843e85
# Dropped referenced: 1553b94bc03b0b9b06ee875bb27e13e2fd521d2c
# Dropped referenced: 88a023216b1dbf1a5b21ccbc38ee2cc53d76cd07
# Dropped referenced: 62b590ef54cb7c8785323ffb14b621ddd07d4518
# Dropped referenced: 8bdb5fa81f332f0c9bd6d86ab6bdadaa2d76912c
# Dropped referenced: 2b5ee62088ac8e5db32de8b72374f37bb370c651
# Dropped referenced: 7f165bc51ccdc1b689a27de8d051b06c6bc638ed
# Dropped referenced: b93fcbe93bddfbb36d9e301d350acc471752fdf2
# Dropped referenced: 2681f211c7710215710997782f4455d0db7a4c1f
# Dropped referenced: c2dafd8ba16b8681ef60b33246a6ab127459289c
# Dropped referenced: fba5ae1579942645910a7be1e5cd87a92ac4873e
# Dropped referenced: 7c5c439e43364106b740113fedd09496eb19b448
# Dropped referenced: be99ed012258a95d2409c02304008c8efa431e38
# Dropped referenced: a2dd61028b032a8d0f1999f78b080cd1dc0f59bf
# Dropped referenced: 8797cbf1601822fb6b35dcd570ef673d1a4eef2b
# Dropped referenced: 495d6bf02e64d93bd8e006863ccabd45eafab38b
# Dropped referenced: 0db88e8758968790c88d874590cce49758c8b7ad
# Dropped referenced: a79b95dad74fe8d14c95d461fc32833a464c2450
# Dropped referenced: eec282723ed70f147d3a660abf2691353416d0f4
# Dropped referenced: 02eb6566bc9e1fb987d02e736e71ea93a4e2838a
# Dropped referenced: db3dd246bdbc1d9159d42d0db378a5533e97bab0
# Dropped referenced: 9664ab17170e0442f35e27d8b3fac7398aa12d08
# Dropped referenced: a10fca08dc142d4303492e74bb1caf670faec89a
# Dropped referenced: 037dbc33e1536bacd39e68b1da452264776cadc2
# Dropped referenced: 959847afc2facb01ee2393fa56a71581119e7f02
# Dropped referenced: 510fa5801e5db103f54366af0247d0d0bd7f122c
# Dropped referenced: 843a994380a1fad5121e0087d8d293215d014e9f
# Dropped referenced: fabf31c6dbc8ae4efc3b812e61c66a06d67c15ab
# Dropped referenced: 9c0b9e0f4f2816667a54838247ff64c24f56673e
# Dropped referenced: 65b25a5a23a8b01090942d5d1cbd2fad5cdd999c
# Dropped referenced: cd6778fb2a30298eef45df02d8739d227d942e33
# Dropped referenced: 7c9bb54e446572cc48658a1150f4a8be01bbe3dd
# Dropped referenced: 507909ec828f2b0299b0a348b70872a1b41db50f
# Dropped referenced: f1c6a45c3582f922b2ebd0aa2d7d76d3c054191e
# Dropped referenced: d843738460111bfa211f06a87d06ab69bb5c03e2
# Dropped referenced: 208f27d1a1bf104ed696892a1699efdb4c31c46d
# Dropped referenced: a6fd5c05f93c3f68b96ef813c93d3b0a8ec18d4c
# Dropped referenced: 2fa7ef41c59ff74bd30405cd9b00bb015c9a2184
# Dropped referenced: b19fbbc966db80d303ec3b93798b75ae33d0ed0d
# Dropped referenced: 88f9b78947d9b42b11e9952b7e61e54228a2b04a
# Dropped referenced: 47540808f3c973687caaae3c7653118f02cf37b3
# Dropped referenced: ed69433ebc7836a8be6ec1dd0703238bc0b354e5
# Dropped referenced: 14619552dc892bf5a1c0bc0bd685d952a89183fa
# Dropped referenced: ff96ed6158e6e3cc1459fa4650d7337664b1ead6
# Dropped referenced: bbb64cf9b45bd7cde9ec2b73f1eb396740f6702f
# Dropped referenced: 8cad133e40dc9be6bc69858724747cbbf6f5e46b
# Dropped referenced: ad90debc20bfdb6a42b7e85ac00994f0be484b8b
# Dropped referenced: 8ffbd8e35b4a8de8b741d1f332d3a1f31325808d
# Dropped referenced: b4b11b7e1280575cddc528df53713b409ed1881e
# Dropped referenced: 66bebfe0ee1adbfd43e7870797cb8ec85de955d5
# Dropped referenced: aac36280603e354eff0258cfe9263e9f8065083f
# Dropped referenced: d60fb8c21613d0063cf61733adae4fa9542d5ab6
# Dropped referenced: d0928af1b87d9b76b122430d6155b257521f3e35
# Dropped referenced: 9597f9739ebdb156ac258fdc558b9e9f6457f090
# Dropped referenced: b47ccf20a66e4fb531c90ae17cb112d52e871a25
# Dropped referenced: 70e50a42977452a7fde035fd63709433a5f94977
# Dropped referenced: 6590674f561b30905997c289cd6ed7ac5ae643c3
# Dropped referenced: bc1a09c765e96f460401d7f5b3f02d538044a95b
# Dropped referenced: 762c78975ccf9a1fa7fdbd3e4c5c371c869eb59c
# Dropped referenced: 3a45d4289be41983facb0e957374694ff363fb47
# Dropped referenced: a92830b94ffb8f432f12eefed50b55b921ee1c1e
# Dropped referenced: 5eab3da80329cd278eed154e32578c949d8a0a36
# Dropped referenced: 732c567a2c323686a043b08bda442e9895e95b58
# Dropped referenced: 9e37bcdf5d3b3659c9c7166e90a0bb28ce7a6e35
# Dropped referenced: 90811b98ffa7a6adafc3cd881d1308f2a2119d8f
# Dropped referenced: 75c2c5966f0a3d3b9b3bbae3d5afd995761c5f9d
# Dropped referenced: 5b525ff5bf8fb70b62c5c487fa9ca6643a2e21dc
# Dropped referenced: 71f3dbb8df7be00bd9d6ce380fbbe5f219c9bceb
# Dropped referenced: 85560ad24a016785122006564767acbdc728c40c
# Dropped referenced: d1d8df9a0dfe92b4dc70f5d49360056ed6f88967
# Dropped referenced: 8aef67b4202f1accd3d2bfd17ba6cd3e3db519ff
# Dropped referenced: 115f91c51e6fe5613de11a3d2b7fda6db3192c6e
# Dropped referenced: 40c8e0b1a8202071dca966674d3d55f3fb3f202c
# Dropped referenced: 2a36c07083d75381e5b4df64afc3ec214334d0ad
# Dropped referenced: 09555d858051c648dc658caedb41205150b9da82
# Dropped referenced: e79ee29633c44402cdf71dffd408f74c8854bce1
# Dropped referenced: b2d49527d3f9ec780faa4dd4b733b7c7b74dcfb6
# Dropped referenced: 8898795c231262dcefac6c6407e898b646e3119a
# Dropped referenced: e7e556351818abac72955664aed38fff912a9235
# Dropped referenced: 6d4be332cb3695c6b0a1c9d9303a8a8d03a50a16
# Dropped referenced: ca2468a1fa9fae3dc3b00acee4688ec0f8f0f8ac
# Dropped referenced: 7b54cb7ba1087bd0a359a7193e47bddd4610faee
# Dropped referenced: e07b502519be6ebfa2f5e8a0920e9be7c533007c
# Dropped referenced: 7a82628a64353385b8f1b6ea9cef981f32c68911
# Dropped referenced: 003e8d2197146d561aa5a8dc343cc55efe5dce8f
# Dropped referenced: 0b7ffdeead4cffb116cde43c78100c969838d34b
# Dropped referenced: 78c45bc9d286eb7e0027f7f70b2fadfa8405d4ae
# Dropped referenced: 7219ac5424180d57c13da42a811a764bd9698903
# Dropped referenced: 1b09e76d05d378a970f930225fd828aa0ebffe25
# Dropped referenced: 301e8358aaf8a16fbe22f40dd999e0360145bd20
# Dropped referenced: 9f360f0f2a25f518af19cf3683b7131e18bfbfa1
# Dropped referenced: 7c9fef757216649b3b0a61c11b0dfcf2c89beab9
# Dropped referenced: e3f061c169fbbb51cbe8d280e8780f17dd02f2d5
# Dropped referenced: 7d578407fafb976a23c42798753709cf2cf63dfe
# Dropped referenced: 2a2d824f4f631edd4b9bf7428bcad21b28e21472
# Dropped referenced: 4aa9f793e96bb4c5fdd640cdccea54dee4a687b8
# Dropped referenced: 421e6aff091ed8a6abf0856482e1908ef5b0f4c6
# Dropped referenced: 80b0f111f9619eaeda3f537b99a02136cd0d94c4
# Dropped referenced: f18540a5c5e307abe9317b22adcf05a0d0ab0db4
# Dropped referenced: 5f5b8238a73ec23b3588db1f886d0d62966f9501
# Dropped referenced: e919db71bdd077e14b38961a7a8846b807562187
# Dropped referenced: 2d8796c7499cc052e9354b6e5f5cf3a3eea7d4f4
# Dropped referenced: c11a37cc5d0f53d900b97701a2ba178cbf9a4fad
# Dropped referenced: e0a0657991b8305bc41a15bfc76e7e94a47b4b21
# Dropped referenced: 1ecb555e2db495fd2f314051c6d180060b2af641
# Dropped referenced: ca1b48c42cfedb43fbbb87832ca59ee38f0d0083
# Dropped referenced: 8e625fe16bb9377a39a3571ec45c65a0c32212ba
# Dropped referenced: 271a960b115831314c3aa7f6bdcdbe6a5c70c8a0
# Dropped referenced: ce6c2c383a629723d5d681cb8cce05dd1422d2b6
# Dropped referenced: 42d74e6b1339d3e99aba996bb2fe5329642eec4a
# Dropped referenced: 0b843bd208540612c8eb6b39bc1bf4247511a849
# Dropped referenced: 2941abdbe7648f286915d531d88d19494d2dc117
# Dropped referenced: 7775f4356803236c575cf469984d276f84dffc3b
# Dropped referenced: 401cdafffed365da7ed5122f936c6d6872d89fcf
# Dropped referenced: 6ace47eeb40aa8ff763693318ebcf665f02170a6
# Dropped referenced: c4bda149590061fef3900fd3887a5c7daa41d71c
# Dropped referenced: e782ee6acca72517aa6c4f9174a5cb93d9c3c5a9
# Dropped referenced: 33297a8f35794828eaeb72899e4c39591a2acdf1
# Dropped referenced: cef1adc8db43ea1e7db91f59a6fe4b47b5ee3b85
# Dropped referenced: 44f5764158b2a65f60bfb7b9d9f438368fa5bebb
# Dropped referenced: 24c10b31aa0b6da8749da2a6309a905ebcd89c32
# Dropped referenced: a01a9a917a1198fcd060e64dfd2d149e35e97794
# Dropped referenced: d99ef919dcfa0f089484e505844bb996992459e0
# Dropped referenced: de08693ff78a13522269e156d485a38cfa2c58f4
# Dropped referenced: be5bd2e17f762c8847fba9a20097a7b96e81e362
# Dropped referenced: c74ac0e9a8443ea50bace1422598f9eeab55bc46
# Dropped referenced: b2812b7efd9524184925352be79d5b923420c752
# Dropped referenced: a607997c595be31d838fdddc563ff431b90a2c9e
# Dropped referenced: 4b12494ce2946f706833f059558791c4e4a79ddf
# Dropped referenced: 04e86ca29412f7c882f38d8826c9a8a61a45d050
# Dropped referenced: 988b4d81d219c380527024f260fe200088ea637c
# Dropped referenced: 84cc89f202f146f8e98232cea2cb2a56c600577c
# Dropped referenced: efb8a8b2bce9f218d58ba8fb6c958586d3b14a4e
# Dropped referenced: 76ad159a2887b008e5a7335d124c148c13e65465
# Dropped referenced: 2ab1b884f95cf77585be95ff575973b8e13da662
# Dropped referenced: a0be6652438b54f577b7353f2df23b19a44afd3d
# Dropped referenced: 763be2b6f257f100e588bc8b41542d22c2c6d7ba
# Dropped referenced: 6a7d107ae27ff0e5ba3a168378cbd3694537c832
# Dropped referenced: a2568273b1f6e0cfea3e009315887680b7522eb2
# Dropped referenced: fb6002a8bfe82aafb9876a1c810576340533ca16
# Dropped referenced: 7499b824c9af217bc3856dd1bed9f7719d33d87d
# Dropped referenced: e7b85db89d5f2311b2e53dcac457cd8d27d20a83
# Dropped referenced: 05b199fc0e63bc3a7975f9112b79fa0d21bd3161
# Dropped referenced: 4a104dfee2541203e20f67361cb79c8a01094b2e
# Dropped referenced: 5bb47375712c0e9a3ecd21bcb73509760d9cd722
# Dropped referenced: 38cd6d2574bfb58c54e9af6b687adbb13469deaf
# Dropped referenced: 5d19802323498c400e5e27eac37b1ea7594bc649
# Dropped referenced: d51c5f49506b1ce7ae4f7e2004b2f1ebd274f79c
# Dropped referenced: 6b95d2344cde43d9ea73df1572864e74772ad6b1
# Dropped referenced: 0fc2fc051c17b86bd910b28d6d3f8b72de338be9
# Dropped referenced: 0e66a378a2414ea4602d1aabda55302496485b1b
# Dropped referenced: 7f7b5836329c8f9643c3c9f23661569bfeafa316
# Dropped referenced: 44a5ff40a568945387bd5fae69aed46e1b187817
# Dropped referenced: c1aa5a2611c3bed4c9fff705d07f3ea78b21854c
# Dropped referenced: 65017b93148a48f5b4a5e1fd52f1037d6caf2f0f
# Dropped referenced: 7881367002ae44e5f447bbc8e4676dfb5da43ba2
# Dropped referenced: 29100d914477e34001565fe6ece45989d4b20c34
# Dropped referenced: c767f7a2ad63250a96408a45e3f301006ec22b25
# Dropped referenced: 745e904df3c047c2a61c754c47e4d31e0aa67c36
# Dropped referenced: ca1b48c42cfedb43fbbb87832ca59ee38f0d0083
# Dropped referenced: ec827069a53a99881236a31d897e41078348e28a
# Dropped referenced: 975c1190edca1c92af6c56bcb0573d999b348479
# Dropped referenced: 0bf1391ce8f1311c1237d350fac305b0895f9f67
# Dropped referenced: 64f9cfe93d71fb237233068fcc085cff94b07475
# Dropped referenced: 14a87210f1b4f1fa9ee318b9b8229dcf05b709cd
# Dropped referenced: 486cab43c8ef43e38d93a653b055637c81d9e6e6
# Dropped referenced: a4158effb0ed41665f06f8461e34e8356f0963c7
# Dropped referenced: ca01b82af781777bd5d44b801636f8eff10e7601
# Dropped referenced: bb5baa31bb51ba261e2620cf131288f06eaf0e4f
# Dropped referenced: 8b91660d74688424e40e8d5b3d032b302bddf26b
# Dropped referenced: aa89dbbeb0b4e886f9384b42cb1a70c11f5c92f4
# Dropped referenced: ec3cd5873b32221677df219fb7a06876fdd1de49
# Dropped referenced: c827f9d1a902c4e266b891e77fbfe57775d6ec75
# Dropped referenced: 569fc7950bc95aa5caf9eac89d613f18752cf57b
# Dropped referenced: 59ab933c32580fe01187c7ebf8fe3394209e4afe
# Dropped referenced: 0ce31427adaebdb6cef09b9f0f2bffb0a82f25dc
# Dropped referenced: bfdcdbb0ca2a866f9ebf4d43d4b4f8ab6671aadf
# Dropped referenced: 08a5ecc83cd0d7c24ac8514555b00aff8fbf22df
# Dropped referenced: f8f251e948f5ffbd81445e52d91bb687141dda3c
# Dropped referenced: c627e5edb08948f894113396330261891bced035
# Dropped referenced: 5d447aa3fc930a084986b8bf2918593d641de12b
# Dropped referenced: e93e02bc5067c4c125d51307b45eb87adf56c779
# Dropped referenced: a54cc76cccfd562f2535b505743e4f14b3a10381
# Dropped referenced: c59d705cec849ec7f0b42172be3b38c00f4020b7
# Dropped referenced: b63472cceaa995fad21ade91441ce1e9aaa2e388
# Dropped referenced: 460e225379b4929455204e84ee0fbe75a9cf1162
# Dropped referenced: 41f5bbdcf5c85b74a9b8629e0a1ce49decd750b9
# Dropped referenced: 76ad159a2887b008e5a7335d124c148c13e65465
# Dropped referenced: bbff973e341bc13224349a385cf977acc3054bcf
# Dropped referenced: 763be2b6f257f100e588bc8b41542d22c2c6d7ba
# Dropped referenced: 70b24fcb952dd746fafb51a87b2cade672ec4259
# Dropped referenced: 694a295bee8ec9996ffe86fdc9c06d779f885fdf
# Dropped referenced: 0973a34318016c99ccfad262a6ef717c44cd52a0
# Dropped referenced: 38cd6d2574bfb58c54e9af6b687adbb13469deaf
# Dropped referenced: 08914ea1ad07faceba93bb30bdc92ca6f140fc61
# Dropped referenced: c96efd2802d675f38431d42fd2c83afbc281175a
# Dropped referenced: 54557847be0b47f53d5abf2930d90c7e26fb6c5f
# Dropped referenced: 5af6ea7ace023930c715990a25c427ba06045b5f
# Dropped referenced: 283c2d8c3e8e40fe99c03edb5fa4425dd8a393ed
# Dropped referenced: dcd599545c10276a0a2159781642b07e3393fbb1
# Dropped referenced: 10f4dd68c31cf4fec33a95b1fd34788e6326bfe6
# Dropped referenced: 91803b78944d617b404f94e62d231a32c92aa1ac
# Dropped referenced: 6bc5232c3baa5455c3ffbecd0b6872839a723627
# Dropped referenced: f02d98bdbeb90419a916816c81806b27b3ba9613
# Dropped referenced: 88a42a29ac469d5d3d8685e7d7af3816f303e534
# Dropped referenced: d6f5e9028a39dd04a99c5b19f95c49770e4aa583
# Dropped referenced: 95b65884e084cede211565144eb89e81f3815836
# Dropped referenced: 3bf78b441ae46119e85c91cb4c16fcf5d837e45a
# Dropped referenced: a7b69d4f73cee0831cf56307077d839a0dfff8c3
# Dropped referenced: c0ea4748929ae46dc28f9fc34b8c27d5ff54bac5
# Dropped referenced: 139b12c37a0d0251b7b3a4322909c5b9893c2fb0
# Dropped referenced: b6b6fe37570c5a9d5bf058a86b6a75bc3149f2d8
# Dropped referenced: c2dafd8ba16b8681ef60b33246a6ab127459289c
# Dropped referenced: 538847c9a1fc2106913f856f497a2080b8a7d328
# Dropped referenced: 7045c4e83cda481449697d44b73233d8ddcca032
# Dropped referenced: e0a0657991b8305bc41a15bfc76e7e94a47b4b21
# Dropped referenced: 17acbb4d82326f24bbdc5841507680398ccca236
# Dropped referenced: 716f9c95397757e6e0a3461e0442f755a10885ce
# Dropped referenced: 85798b2e922d715d2dcc5d84e49a6f8861777abc
# Dropped referenced: 2b045cb06e79abcf3265a2410b94fb7e10552a65
# Dropped referenced: c8c77e371f147fc7eeda80b1b8635a001d9acb3a
# Dropped referenced: 08a5ecc83cd0d7c24ac8514555b00aff8fbf22df
# Dropped referenced: 4074198ea76abfb03c2024de8cf462a11daabed2
# Dropped referenced: 7200ff3d863fcb7e92faef37f7cd133673069ecb
# Dropped referenced: aad1805ae4ba6e23291312a921463124c077b0e3
# Dropped referenced: 87cef5ba5bb29154704cb81de2376ff5360b6a6f
# Dropped referenced: a4e9745ced205b02758551abba16da28bf8b2f15
# Dropped referenced: 92f5423cb33b329332e9faca004314f707096d72
# Dropped referenced: 19b3ccd216afa7a9530669b11bc19d8190e5c13d
# Dropped referenced: 465a56ef69556633b1b19a27a0a8520012c696e0
# Dropped referenced: dcdf9294d2bff9abbc64c3d0e1880bd89b2d2e77
# Dropped referenced: 44cc5c0f0ee3a49ca9148d5fe9a364ecea80e106
# Dropped referenced: a3fbb4954dbb3c42e9745465540fa6fb9ede38c8
# Dropped referenced: 10eca92804935b3cfdadba87d7ce4dbfdbca5d56
# Dropped referenced: ac9a3dcf83d9fab520ef59b9dd2c5221c7ec6b9a
# Dropped referenced: a4f08d285a7ea049e78564a4ca06c5403af4bea8
# Dropped referenced: 7f17bfd8fb50fba70e95a89ca575fa5bad9fbc40
# Dropped referenced: d1316ff8a5df16650aa7df9f31c149073a9fa87e
# Dropped referenced: c42808469839b08d27f59fb9b42868c2621711ff
# Dropped referenced: 5033b4120cf4e320a1db325a1ddddf4294021641
# Dropped referenced: 0b04ce4d1025b2bdbd8ea2038f954a508dceb891
# Dropped referenced: c6b16f9e14a8a1eb20575f21329cf32bd33cfcf4
# Dropped referenced: 7968b4947500c2df2c26da33d82e3e84d43288fd
# Dropped referenced: 7ab93b4e25df1b2c6877e0d02d0e6c03a86b77d4
# Dropped referenced: fe5397f0b80d0cdc8689f144278bce3ed9593840
# Dropped referenced: 6314553dd70d7e708e0ed64080709a67b9475e7f
# Dropped referenced: c8f32fd593308e6a5371070fca35f78bc84f49fd
# Dropped referenced: 1b6e32276958a0d606694d66649c25caf983d16f
# Dropped referenced: 5fe3a6c1a599ca10536bc5ab0df16b7ec0820cfb
# Dropped referenced: 303ea1102a409a2f12ae10568882a65b239a76c2
# Dropped referenced: fb10af78e0c1a02abd8b5e75e910cdba1d083e40
# Dropped referenced: d64b674cb5632d1e17701d5943bbac1013b1c3ea
# Dropped referenced: 8db3dc5390a0fc7bd4e605aa493eaf5e42abaea6
# Dropped referenced: ba6df13de17ee4fa2d966d7fefd44d31860cff27
# Dropped referenced: 27ca3385ec3f7eb3289a10d3b3168f3fa0c78627
# Dropped referenced: efb552dd305546bd887a76245cbc08ec0b25ef8e
# Dropped referenced: 3b84991c4b7e8d956ad72015091066055173284b
# Dropped referenced: 35fa23c9f5577761ff79fd14356736570c43b68a
# Dropped referenced: 872d0ea89c023a483712a85af2e315d7c015c5ce
# Dropped referenced: bf0b941c5018c898458c880c19e29e6b9d9dc402
# Dropped referenced: 6a690e85b1023e5373f8bb7d06e8cc4dbe8d1050
# Dropped referenced: f734afe22d544a3d398d2e29a4d04c1078f96018
# Dropped referenced: 7f165bc51ccdc1b689a27de8d051b06c6bc638ed
# Dropped referenced: 538847c9a1fc2106913f856f497a2080b8a7d328
# Dropped referenced: 1b45d0463217679c8593acf290706bb36b2b33cf
# Dropped referenced: b29f01a10617bd7c6db2d621c0efc676747da07b
# Dropped referenced: 9bd13275315bad3be36725a90b6231f237c64243
# Dropped referenced: 751794c4fe013e203e048c4037fbb076c2ff1a5a
# Dropped referenced: f1cd825e5ddaf789aadfdc0e50e2f1d7531be7a6
# Dropped referenced: 8797cbf1601822fb6b35dcd570ef673d1a4eef2b
# Dropped referenced: eb25887603f7a1cc8e241c9f0f4b1a0e00e80544
# Dropped referenced: 6d3df0b24abbba760929415df00f90f1d74e9f70
# Dropped referenced: 98b7fbce1a5fabb7466c9e4ef38ced625e13596b
# Dropped referenced: 0c8c2f3d38f986e6a4e4f35fc64a633ba9fc7cf0
# Dropped referenced: b328b11dd869e19085af0fdbe0ce0f6529bcfbdc
# Dropped referenced: 4182a2c7ec5e47cc44aaae7956a1d6309d2a2749
# Dropped referenced: 504deefd8a93c789ad8036b945c497574d0ec2d1
# Dropped referenced: e1e8d95e92290099f01598a6ae0dce5d50fa8faa
# Dropped referenced: 364c236ce3ee18c17138c185c91037930d14c07a
# Dropped referenced: c943afb901840397b72d78d81b65d78e8137121d
# Dropped referenced: ac1b778d19f4cc5a9c6a901609b155422dd6ea5a
# Dropped referenced: 518bd0ddf41b09623619416d7986e6b3aa87e05f
# Dropped referenced: c65ecfc919d5158c7d215375c7b922648d3aecef
# Dropped referenced: 38f97960be98c9b523befc21f8f1724715d4184c
# Dropped referenced: 291e5f7308e2af84bdc06b84afa99fa6419e7ddd
# Dropped referenced: 28980d9158903a2cdb62224f0191b5b02be5af1d
# Dropped referenced: f69e53f8c5b497815510cbc46741abae7a340968
# Dropped referenced: b8ad7a81e1f0aa46a57d87287c6fc984cc380fa7
# Dropped referenced: a01134fd69f340824ee29bce23e86ca859c0bed4
# Dropped referenced: 65b25a5a23a8b01090942d5d1cbd2fad5cdd999c
# Dropped referenced: 4f615b08bb5f20f2fd0c5d3b2007fed5233aea3c
# Dropped referenced: 0707802e3526d1821b632f695556927735846c10
# Dropped referenced: 735415802c2ba4ff66c4069032a566d5767bccaa
# Dropped referenced: 716f9c95397757e6e0a3461e0442f755a10885ce
# Dropped referenced: 2c72e2e3204210f26544d0b1543b2ebb5cff8294
# Dropped referenced: 9f243307d8d766839164928d2861b7684a8354df
# Dropped referenced: bcef07ff21a80037fea276da15b90c993e467401
# Dropped referenced: 82ac204a4c0b0714edd1e1c841ea7faecced1a4a
# Dropped referenced: c903ea92abb6e380a014ccba164520fdc4d9c63b
# Dropped referenced: d3d327474f4c719563599dbed84167c9a4cf5ecc
# Dropped referenced: f3dafb50f9e295c3834c49ffb1c3f6686b6a6b6e
# Dropped referenced: 3c26a8adc676caabf6b9bc0ba7db8019b628c2b0
# Dropped referenced: 913db5bf6d8c55c3d597674f5f3e15b1b6bcc387
# Dropped referenced: d4b22739fbbe80fbc417b9b51a4eceb6fb96b787
# Dropped referenced: 08236ebb2bc74fa520359c2ca88c544f1cb86692
# Dropped referenced: 392595fbd33a98d23264cdcdefd27f7b6d9c5f23
# Dropped referenced: e28d2e0cd84ad04865d5493a039a534d0c803574
# Dropped referenced: 99ecee2eb36066532696568539f47e99c9f84aff
# Dropped referenced: c7b87cd036268a97c8b58e3aad18e125d65819b6
# Dropped referenced: cedac6abcc661f9b9c31ac7cd668c844f3fd2d68
# Dropped referenced: 0911b79ff4a7b3c4dc573a1014c0258068002251
# Dropped referenced: e38a9755bd991b43d6140e4aaba8d56a562b17ab
# Dropped referenced: 572cdb34e14a0a50f0c053260a3e08a59bda7e23
# Dropped referenced: 052b2f34fc3770427fd6417d6ea595603f09ae8d
# Dropped referenced: 0b93901e11e0277e04fe4f0133846250d0be7f89
# Dropped referenced: 094caf2774a91f5d36c41873e4be9bd617160f65
# Dropped referenced: 28143764f7e04e36af79134798dfe1cca528bc93
# Dropped referenced: 9ef3ac8e56998fc061cb55ffc9852e7e3cfe28ab
# Dropped referenced: 51f6cccbf208249294ef33829862b5e9963b399a
# Dropped referenced: 9219dab039101bb56f04f054eb8eb558cede1d0d
# Dropped referenced: fb936e4280daa438d0034e81dfb9b545fcaea9de
# Dropped referenced: 96e3fbfd348bfb1d3367fdbddb11122b6f22c62d
# Dropped referenced: f35d9d2e82f967c1f4ea362c5141b5aa203b9f1c
# Dropped referenced: fb842b9644edf78d74865e809375baf1de8caa20
# Dropped referenced: 644145f29d1463647821378536994e03f4fe4964
# Dropped referenced: 277d880dc7ad8275162ccf7476bb432b5bb50338
# Dropped referenced: 1382b3f615578f77f5f28d2badac66b99bee7778
# Dropped referenced: f4ce6b583d78f5a39e342848f3e3d90b3038522a
# Dropped referenced: 2c6fe95cdcb4aeca4bd6c0099fefa867fca27652
# Dropped referenced: d7acbb22d2b0dea61c876ddf920f1b4858df958e
# Dropped referenced: 35d12e8c5dae14273434a244ff00b2466d4b4283
# Dropped referenced: 37e0bbc0df363fc579796a79bc68cc39fd7ba311
# Dropped referenced: 0f18bb767a122a1bb112bcd6a70c8f3061951b05
# Dropped referenced: f94029da4e3ccf30281a570b8c52a36945c7bdea
# Dropped referenced: e5413d1e213c5a4179a13d54b07e5fc67765fe01
# Dropped referenced: c0223f85e51ada84eb6908e49279da4b237ef7d6
# Dropped referenced: 254e64a79124d5e34631264610ce75ce6d905106
# Dropped referenced: 3b45e3ecdc51e12d2e4f6a6f5c2fec6c284c21cf
# Dropped referenced: 191f75a9023ade43c810d7a24a576e4fcf0f0148
# Dropped referenced: 8b35863679c836b4b9c232d4920315720d3f0f8f
# Dropped referenced: bc5eb1954c2f424e4dc950cca283365fdbe8cbc1
# Dropped referenced: a59253d6c4e610c29cb34255a725ef588585c921
# Dropped referenced: a642852287735b8b42bc166994b06eca7d4f8f26
# Dropped referenced: 5aa410be0d2790ac7e7154b26df9a1670fee36ce
# Dropped referenced: 6c7aaad649595da66c93c7a59333e44adfa4cbf6
# Dropped referenced: 838b2b511ffd340f47a5d05a97e1fe22e3f6aece
# Dropped referenced: abd898159117ccb5b18eff117d0ce3f40d8132ca
# Dropped referenced: 24ba68c62d67c354b91b815ee8db6a4c629aa44e
# Dropped referenced: f77cf2ebf074f7f2c72bbdd757857dba727ac1b9
# Dropped referenced: e79ee29633c44402cdf71dffd408f74c8854bce1
# Dropped referenced: ec7cae8952935bcd7942a4bd8578a2c62b6de6e2
# Dropped referenced: 35fa23c9f5577761ff79fd14356736570c43b68a
# Dropped referenced: 01004117a69a452be4ab49956f3fcd51620ac4e5
# Dropped referenced: e3044437b9b45012bc79ce1d926b532d998c2d9d
# Dropped referenced: 7b3cffe8555501bf2a78c0efecf2b04b53d66ad9
# Dropped referenced: dfe16eeb46009f7405bfbab21d7f3443f744e0e2
# Dropped referenced: 6bc0363594fa87320fd58aa8751762b048b29ad5
# Dropped referenced: a12d3d00cb01deefba372ba238111fa8952272a5
# Dropped referenced: 30e40a185f6b6f284f545963961bccbbfecc1dba
# Dropped referenced: 7684d36482bde1691acc30a7c9a8f61b97db66ac
# Dropped referenced: d291cfd6dbb24f07fe55cd60b99f0ea5d74c0e7b
# Dropped referenced: 2b5ee62088ac8e5db32de8b72374f37bb370c651
# Dropped referenced: 08e63bc6670a0c6fd338d4e24a3062fdf4abc42e
# Dropped referenced: afc20e07ba2052da784aa1d9a74962cf346e06ff
# Dropped referenced: 6bcf48edf023f566f83cbcd95252c319738f0205
# Dropped referenced: 1e3ae287d55171002211ab991910510e07d50323
# Dropped referenced: b36c51580a701bf205d6dad09c7810fc3ab5bbb2
# Dropped referenced: db3dd246bdbc1d9159d42d0db378a5533e97bab0
# Dropped referenced: 7df8cfda2681705eb085ce1c34d3720a3c614191
# Dropped referenced: 3151e4d30eaf07ed35081e6b2cf5cbb010e461a3
# Dropped referenced: 43c4c968d41d3d65cfb3d745fec00d7d361bdc47
# Dropped referenced: 208f27d1a1bf104ed696892a1699efdb4c31c46d
# Dropped referenced: 19a9a5a02e914a815a844d93577f8fbed9598d27
# Dropped referenced: 2fa7ef41c59ff74bd30405cd9b00bb015c9a2184
# Dropped referenced: e6e180b36fdbd4569ac9e5b399f01de03a6d65ec
# Dropped referenced: aace80d5c044586c4878e8c41522924775b25336
# Dropped referenced: 796f95cbd654c28c93e6a8cfe616d486ebceab70
# Dropped referenced: 7caaafaa2c4fad7283f9ac0f65e498ccd5045af5
# Dropped referenced: 828155f2c1b7d95d1d33e86cd3260db7f0da9384
# Dropped referenced: d0928af1b87d9b76b122430d6155b257521f3e35
# Dropped referenced: 474b4b7cdc2c19cba8b47f181c511eaa7bb14cf6
# Dropped referenced: 7cfed21c37a2f1e142b10e7ce0594a516caba1ae
# Dropped referenced: ed4ebd3b29ef7e8cf20059952d623d24c5f1ea74
# Dropped referenced: bc1a09c765e96f460401d7f5b3f02d538044a95b
# Dropped referenced: 9af684c76dbd08ce9b166c37489321ba27a2e2e0
# Dropped referenced: 401b99c562dbc5ae1e9e931e75df5eb7dbe2956f
# Dropped referenced: 09555d858051c648dc658caedb41205150b9da82
# Dropped referenced: fd022d38fe3322d127efd853edf495250163da3b
# Dropped referenced: 8cc3f96fe5610b4a82c326977150eb2c6775c703
# Dropped referenced: ece9a23762b0d350b8d63469cb9577e4a7398031
# Dropped referenced: faad2aeae53ed210e069f24981ece2667730b2da
# Dropped referenced: 51d261a2df0237c6fd3353d4da7675b244f9e15e
# Dropped referenced: d9611d0132391df3dd4ddf4d4d9e921f50daf035
# Dropped referenced: e07b502519be6ebfa2f5e8a0920e9be7c533007c
# Dropped referenced: 45383dc115a132c070e722d75f68d4c86ca4f524
# Dropped referenced: c760e0246bdfd660f681eecc7dd06ae82e6761ba
# Dropped referenced: cd540e7cd774c0c808c5fbfd73bf4f9782c94004
# Dropped referenced: e3d123358dd80d66f0ab0c4ae6a6f2f26d11ba0e
# Dropped referenced: bd960408b06ab088406f3a24eadcb4e9e4857959
# Dropped referenced: 0d8ea705a662d623b5d7076d75b4f967f6e581c9
# Dropped referenced: bb0f619b872821b8e3716cfe85de708f4ae510ef
# Dropped referenced: 992327a493107139b5566859c904ac5d0c47159a
# Dropped referenced: 5f44060d0a940976f9edf75a2300e28b69914cb0
# Dropped referenced: cc891ea358d75ff6f73b5fb325844a4f471c962a
# Dropped referenced: 14915de7d25e475071a376712ba54764a0cf9a31
# Dropped referenced: 38d008ca0271bf56ae185f947b1e74f473f6f4dd
# Dropped referenced: 7b4f9f27720d1c7deeb41cea4a80cde8fac3f910
# Dropped referenced: 158fc4d866d7fba30f44ff6fb15c89a0aff97291
# Dropped referenced: 20535617d88aed2e88aa423f0d9fea43da70878a
# Dropped referenced: 6322a19ef371ea8ba12ee0811f2d9b97f9d35fb0
# Dropped referenced: 59333f466ee95c1b36b1bbbc9c754d6c62f7d68b
# Dropped referenced: 662034fea05b9c21f915c7979a778652af1f4df4
# Dropped referenced: 19672dd273a1a114357e1a0aff843f2ca9ee2e3d
# Dropped referenced: 7348432aded66d0a0936496adbc997fdc44a8014
# Dropped referenced: 264ce4449468f38bc6f3d14d363cb434bb80537a
# Dropped referenced: 567db1262529ec7b9144269695314fe0f9e76b32
# Dropped referenced: 95c3d286d4820faf5991d6c2b12a54dfa11acfc3
# Dropped referenced: f37ff36d9992d47f91ec6f98d395c024e651e435
# Dropped referenced: f080136bd688586c7486c99b14ec086e2b18cfff
# Dropped referenced: 2f5b8ab7c8ff3c17688482aab4022fe89df7fb29
# Dropped referenced: fa2a5abb2cf23d5fba08831c42e6f6b1aa3f2b29
# Dropped referenced: 1c734c6f1b799f1fea0e679cb0224f996d91f19e
# Dropped referenced: e1625352c7b6e275ec9a63984a5af25a98032671
# Dropped referenced: 5f8580164c000d5423b5511cc90e8e6a3e49d906
# Dropped referenced: e2b87cf72a447c0c7f6f9939fffd1c0f02e8b863
# Dropped referenced: 5952c2f541a8f777982eb07ada0d2a285ab7709c
# Dropped referenced: 07d796b53f62a1c0e607712716c51e9e72db7baa
# Dropped referenced: f74653aa213f9efd852c6167ee09ecf5a28206da
# Dropped referenced: b13c24a27cbb8ac941e59838fb7ceae8aa72857f
# Dropped referenced: e080115983248e00214be4cd624214bac812e72c
# Dropped referenced: 3d957a014ac40abde1fa591279300f3b6585905a
# Dropped referenced: 6946ee1fde59f2d6f2deda06ca558d6cf3b54f59
# Dropped referenced: 57c14216f028e792f9020ca10a7242e02b0bf712
# Dropped referenced: e963d277ff85a4d2ea74bc96e17a7ba77b18be9f
# Dropped referenced: 705f563448e7d49f804d940f29fda8f2382f1554
# Dropped referenced: ee65c86b48e9cdbbba17b755dd5e18eda8108659
# Dropped referenced: 4e74ba8af86ab76a57c540877136cddc74fc9028
# Dropped referenced: 1cabed62a2299e635ce83a61c182f0d31452811e
# Dropped referenced: e2d78523d97dca5910140400c1ccea1c8315e2a5
# Dropped referenced: 14279d2575e40565b0170855617e9e2a456b0220
# Dropped referenced: 154bbfb69c1c6201a1d571b75f8d997af48964ca
# Dropped referenced: 05cda63d15fbaa78ecab27a35b33bfd1b100d5b1
# Dropped referenced: e12e9c4c85dd8c6f6762ea9c6be756d3b89956ee
# Dropped referenced: 65b0dd7a7cd652e7d2159d76b79db00e33375b91
# Dropped referenced: 54a1cb499480db40487f6106e74a7190cee943fb
# Dropped referenced: 274e1488bb1d38d14a7a8ebf5d390bbb62a24bcf
# Dropped referenced: 38996c9192506097d419d2459dfc651d7bf29afa
# Dropped referenced: 3917eb10de7b5a3efdd51ce2768e5b3b9b515d27
# Dropped referenced: f5d2a4e0de8b188ad3f2837d7d5ed7482687df89
# Dropped referenced: e190bad744470a9fd4e4c46ed8e39f0ccc445589
# Dropped referenced: bc5eb1954c2f424e4dc950cca283365fdbe8cbc1
# Dropped referenced: ad34d151156c815c9703c283e583908237f73e18
# Dropped referenced: 5e557cea7dfdb9cf20c6332e53aabff78301f26c
# Dropped referenced: 975c1190edca1c92af6c56bcb0573d999b348479
# Dropped referenced: 95127ce015b9c433a2c4ccc96fb4ae1f56e9516e
# Dropped referenced: b29aa0bfbd310a0624740eaad496bcd25b5683b3
# Dropped referenced: 0d4e46af2566b476e136805882dbc076bab952b4
# Dropped referenced: 796f95cbd654c28c93e6a8cfe616d486ebceab70
# Dropped referenced: ed63f501f204e79d92b61d1cb0cde1480d25e1b9
# Dropped referenced: 514e133f43d0f0b2262637840797cd9070462e88
# Dropped referenced: b87b4a904b9d65fc1cd2078241cda42c68985a90
# Dropped referenced: 8f9947fe54389a504399c0a9996e88ef8e212bdd
# Dropped referenced: d60fb8c21613d0063cf61733adae4fa9542d5ab6
# Dropped referenced: 949be6f0ce8b4df2e27f94fe3640c52a79a18404
# Dropped referenced: eebbdb1925c9bbe5c5b914d6953f5c55377081f6
# Dropped referenced: 7cfed21c37a2f1e142b10e7ce0594a516caba1ae
# Dropped referenced: ada0439ca77c91c08f577d9311502a4771dd58b6
# Dropped referenced: 2df915f0f7f2fad3abdc5ae69a22847e5016733f
# Dropped referenced: d8e8a35f49cf7e382072591ad01f9e1f02c4c7f9
# Dropped referenced: b8117b3c652e40e317250b4ba82225ece7b4a980
# Dropped referenced: c1c0960ae655b9cf06b83b2b808b2b44fe81ce6f
# Dropped referenced: 8b4ca1b28776301ee199600efa7016bec3d0781e
# Dropped referenced: 8d8e90d9b4c1f267ce1936753e1cd2dff7aae586
# Dropped referenced: 889992c16bf7c307efee618ad2133251b3d850a0
# Dropped referenced: 2c1e750237e150e15cbae82b44044271f0e7a76b
# Dropped referenced: 8a8fd583bd0d1f8e359fe78d75bb98720cc5ff59
# Dropped referenced: 4eea0f24720e62961e4466a547ae8f5a2d94d457
# Dropped referenced: 17f278d11d3667d0facd518252c2c80d046eee2c
# Dropped referenced: 9af684c76dbd08ce9b166c37489321ba27a2e2e0
# Dropped referenced: 2d41e5956fd5a73e176e1b783ce00ab207184078
# Dropped referenced: abd898159117ccb5b18eff117d0ce3f40d8132ca
# Dropped referenced: e32228b9abe8527fc88445932c67cf89f17a4393
# Dropped referenced: 1a6bdb96f8cca65bd6446dec7fe27826af481d75
# Dropped referenced: 2e1ad20ee6e99a923125bcf8fc3c1ba9a6c589f1
# Dropped referenced: 2a0476fcdd85cab98027453d4d5fce89206d3f93
# Dropped referenced: e3f6f39577746cbf9297cc981a1ccbe6db557b82
# Dropped referenced: a017473b0afb437330372474ffa66cc4e8b3cd9e
# Dropped referenced: 378c2b818f6f90fe48c4df310d8264168cf33e26
# Dropped referenced: cf122a7d82e4a8baf1f869193509a7204b7ab088
# Dropped referenced: ad6412fe6e7d2466a86e465beab572c5256e5654
# Dropped referenced: 052af1b61cc7ad0346645c26e0990b0bde2d103f
# Dropped referenced: cdc070bdbaedcc8dfbb1458be4f1aca8d65fa45a
# Dropped referenced: fbbc03c619bd159f8cb5b516305d91c08bb4c5c2
# Dropped referenced: e13f0d1c7bba268ecf1bdf847b140e13c4e8619e
# Dropped referenced: 4981f5b17a4cdfeba46538a0a74c36caa3d8bb14
# Dropped referenced: 02af2589e44a16ea0a01dfd2ed7dd320cb0b829a
# Dropped referenced: a8efc64e7ecd5244e1cffce96553870d75ba5032
# Dropped referenced: 1c53f6fdcef2afa88afe77332a9aa0ba2eb347a8
# Dropped referenced: 1084bc3f1654d158ea67b60f315ce17d9943853f
# Dropped referenced: 93653f110bfc7f7f6461396b9b446340ca26b63d
# Dropped referenced: d37552c042f18f4d867c324170f0686c7106a8c7
# Dropped referenced: ecba24807996f822bb107eb0b997068616330a4b
# Dropped referenced: 99197d2f2382c7e2143383e39b679b878bd366ff
# Dropped referenced: 95cf424d8bfb92a1835291a915ea6baba37e6414
# Dropped referenced: afd91e6ae269298a4ecca6a37816a8f519d8fc93
# Dropped referenced: 51d261a2df0237c6fd3353d4da7675b244f9e15e
# Dropped referenced: c95f6d44d26ee35f6138481abfaf3669d26ab5a7
# Dropped referenced: 2b2f9ac78ab81f8cdf286271d923c4ebff0fafef
# Dropped referenced: 01004117a69a452be4ab49956f3fcd51620ac4e5
# Dropped referenced: 003e8d2197146d561aa5a8dc343cc55efe5dce8f
# Dropped referenced: 2f2c1a306124f594c0d67572fd74c2b79040acb3
# Dropped referenced: 0df1973b6fc6f0ab2aef44f819cb900934f28e7c
# Dropped referenced: 99d5af0a1bd2fa47d2d42aa05391b1774a7879c2
# Dropped referenced: 39560a30c0ce606678f211a32065da6df419c086
# Dropped referenced: bce0ffb7fd09c949c2634221ed9837c693f71fc6
# Dropped referenced: 9097f35eee01909eebc34f60d967cd87b462a36c
# Dropped referenced: 2f945a9e8a5fd9ddc5faf25a2d4cebdcc9a3c739
# Dropped referenced: ee7363ba39bfc3dd030844933375d7585c7c9b66
# Dropped referenced: 2c72e2e3204210f26544d0b1543b2ebb5cff8294
# Dropped referenced: e3e58844263d2f959bc6aeb13cd440357b5949be
# Dropped referenced: 86541a2aa1737faf37c2f9e04fa07a9402e891ac
# Dropped referenced: 83004c7e023e353ea232c674d925f154fb2fb02c
# Dropped referenced: 5c184668f919c0c161596515f8e8f46e7c644a7e
# Dropped referenced: 66e72f656504fa13ca447ff76ccb1586be7f8bb7
# Dropped referenced: 5bfa8621ef0d4c854cc17305d81a5a6f04bf0c74
# Dropped referenced: 6bb7acd1d8091bb867f5456c76a437bcc2c5a76e
# Dropped referenced: 71c6f86720b5c6daee0c16099e2d95d9dd5d77b8
# Dropped referenced: f3eeb00e12dab61824ef3b84bc7715b04b19bc54
# Dropped referenced: fe43622218848a3c11177a35e909a21392704d2a
# Dropped referenced: 945aa9eb1ea80ad8684fbd8eddf174056493162c
# Dropped referenced: 2199fb996c064f39b4611eaff513302ff035cd07
# Dropped referenced: b8199cea1a054d120c41e67d492108b3c0b91678
# Dropped referenced: dbb3496f87320539a63e257caabb740d7e9a0e80
# Dropped referenced: 1892e74e7cc38e1b70c02482bbe0648464178d8b
# Dropped referenced: 77c1f6f24afc317364e5e55f03f219bc5cc967ee
# Dropped referenced: 474d7e1ea3b5b64103a7918d25b855555a748a47
# Dropped referenced: ef8e7e80e55d2e3e3084db0ffe5fef972106e86f
# Dropped referenced: 823552b40432ceb08e819c7422f126308217f6d4
# Dropped referenced: 29d1ee3e641bb945d3cc5de8a006dba8f172f3fd
# Dropped referenced: 97a13978dfd5a834ed4a2195473084be5e696b5e
# Dropped referenced: 0c4ae71d9c018942ccc2fc3512f628cd74087ee7
# Dropped referenced: d6c3ccbfc94a1dffcf9251208f92a2ace2ccff15
# Dropped referenced: 68693c4afe678924c7a6b51a8610a18a680624b0
# Dropped referenced: a731e1d4b4960b3cb137700c1d236439e146b705
# Dropped referenced: 8c28caad5c4286e4cde8a73703ad5bc00c199d84
# Dropped referenced: c4ceac79f223c4da3756c9181150fc8a0772355c
# Dropped referenced: cc776ce3227eec04a5300f810272926e87e7f52a
# Dropped referenced: 0c8ce55c06dd8bf62313a17dd315a7aa344b484e
# Dropped referenced: 69f1fbb7d6e31a7930f6f3c7d59e864bda33852b
# Dropped referenced: 87f50573ccbffc38c86232056475f65b0f6e77f8
# Dropped referenced: 6d5b1cec74e7277bd4f63f559cc8dca27e0aff33
# Dropped referenced: e32a66e965fb5e7525bed4e316b19df7512a1e43
# Dropped referenced: 1ede6939851865aa31c40fe67255850a08e34ddf
# Dropped referenced: 234236d1cbd9cf1ff7152d6e94f4a89ca37224bc
# Dropped referenced: 5497a26077c0f9a81458631935dbbb294846eaa2
# Dropped referenced: 442bd414f5ad3c216d80b3340a1394545f247e3d
# Dropped referenced: 435c755a6c573da0e213fa6dacbf5197c2f0e2e1
# Dropped referenced: cf4771415b0590b24d48229e603c4407f9fd10da
# Dropped referenced: be0a787107ec9ebfa6b5d39da9809ae8985a97f7
# Dropped referenced: caa5369a658a235e58c191b5a8e067a09d907a23
# Dropped referenced: 83f783d1bba86022aa457de3fc41605f1721b1de
# Dropped referenced: fb0b9bd3c03877f237a1a9f8f83b67da9499e2f7
# Dropped referenced: 49a740c36c20d8d24ce2104e2b36314bedb96a9e
# Dropped referenced: 2edb1480f600fadb616e662bbc4dcdcdc2eac5ef
# Dropped referenced: 54b6b2bbe1a0ed42423c905ad6e564028af3f1d9
# Dropped referenced: d8811f242efaaf00a32fa3da9b2eb424d483b7ae
# Dropped referenced: 3ea4734e97786569fed11cd7cb37bcb4115d2a87
# Dropped referenced: c26a70e61ab6f3b6085c30c1fdfe901301f0f74e
# Dropped referenced: f7bc58042087b7c7bb39109711f356b65d6ca4fd
# Dropped referenced: a02aa6ee081720dab4a072349e54ac6aa03fe5e7
# Dropped referenced: ebff42a6c52b6117e0cd8d241aa8d961a889265a
# Dropped referenced: 12b9019f99a315a137400389ee7c6faa4cceef35
# Dropped referenced: e2fa49d57c46b076c4b9554ec775c2bbbf397716
# Dropped referenced: 7e8f728c62b49afeb5b4b17c94d9991c671a1d36
# Dropped referenced: ed008d2c0ec14a9f184d89ff95b96233c5ef2ff9
# Dropped referenced: bbc066520903a94730bac1dbadfbca9e5b589c15
# Dropped referenced: f9d4623ac4a61dc8ebcf4de8d5c631f5dbc7aeba
# Dropped referenced: bca39fcfe71898be91c12e75dcb786d4c9da45c1
# Dropped referenced: dcc2436955632499894fd6d2eb4dc435fa8f4030
# Dropped referenced: b89427edf20e03e4159966d47e577c06dfb2abec
# Dropped referenced: 6e5cd7424f92c0e891b11c886f648f0d9d57d1b3
# Dropped referenced: c10fda22d58504a9acf6696f061c78b41af99ced
# Dropped referenced: a8bfd8b152e52c81c89c6ed4b51eb2d69b6be518
# Dropped referenced: 37076bedf4a2126d4b936dc550916ffc64b53ec7
# Dropped referenced: 6da88ba815e68bf7d5e9388ed7b9b577d4f5bbc0
# Dropped referenced: 4b4322c16c169efb350e6ca3ceee3d4b6c104e89
# Dropped referenced: 0390e891b23e78c84b4caa1072072b9b99bf2ef1
# Dropped referenced: dd66fa021e4105b5d98d9f458f97913ca2ef9704
# Dropped referenced: 3b3cd40d07a9e07c23de1f7dff10b67166882459
# Dropped referenced: 3ca3338ab8606253407e58cb9dd7a6dbd4e9ae48
# Dropped referenced: 7476ab29ae435fbe01b8f4af19eef62843f57192
# Dropped referenced: 6152a09d72292ba949ce7eb687c0dea670e94e35
# Dropped referenced: c163aa86bb67a82b773799a39f5b91e3e188a7de
# Dropped referenced: 16ac6d7fccbee1b52fc6168a0fbeed8215e1c6d7
# Dropped referenced: e556574652ffe595ad0f6e9824d46fa2ae60c037
# Dropped referenced: 72085ffec576a1302f3fbe22f454419465e55994
# Dropped referenced: 2199fb996c064f39b4611eaff513302ff035cd07
# Dropped referenced: a88dc82b2de759a51677620e293c9382da718244
# Dropped referenced: 2888b403ac0e60cec3518d848de29160ece364f1
# Dropped referenced: c4db9ba56c333fea42b598820a58b765b1cfd712
# ...
# Dropped referenced: 2d472e1fa3568c59fcb8e0c0c1f6d4fdb9799b9f
# Dropped referenced: 489b6a50571e91521586db3c9292a87074af6328
# Dropped referenced: 8d649c752cdba9b9298a650c3b026ca150d17b04
# Dropped referenced: 8d03f2559e0c852371568f8d0ea51c33e56c5e09
# Dropped referenced: 954388da87e0cbe48a7f64cb8270fe1bb5fc82ef
# Dropped referenced: d9611d0132391df3dd4ddf4d4d9e921f50daf035
# Dropped referenced: 084da26797ebaa448bab831eddabf50a96f4fe59
# Dropped referenced: 01f0f919a2e64fea0cd6ad605d84907381b24078
# Dropped referenced: 21f16c96b39fed726c3c661d4d9a19d1a7d4288b
# Dropped referenced: e3fd3c53979f9b871c1c8071bd6c0d716a1cacf9
# Dropped referenced: 5e4e92dc6ae0571e03b06cec1393d739cd68fd91
# Dropped referenced: 535234046de9ba89a1a4f09feb9ce071e18596c3
# Dropped referenced: 4e3eec8e23b8c5a5dd442b05d3eb70e9a7d15559
# Dropped referenced: 3e031756b0a89e4c4fab24931e1a23244a87a24b
# Dropped referenced: 09531511b610513f81e119c2bdf7df45d663dd72
# Dropped referenced: 3aa5de8f03c140b9ffa74f6dd53d21461b160eb5
# Dropped referenced: a5426c4b22dc783e3bc06a8172ef28d2348e3886
# Dropped referenced: b2bd4d99884df3f8baceddd6fb68fffcd2dd7e20
# Dropped referenced: 57b03375593ea566d9624c54115730d54506acaf
# Dropped referenced: 80e645771530455589072f671525fe0bc75c2d24
# Dropped referenced: 9ac8020c2429eb95d1713f1a4c39888167752cc1
# Dropped referenced: 7deb870605d23eaf2b75b767ca0fae74a90ad22c
# Dropped referenced: fd2978436a8350c9a6cd7e0076c5cf4164ac6f2f
# Dropped referenced: b1bf03000f87f82109ce2286306f1212e791a801
# Dropped referenced: 146a88d039e47941407bf699dc7852fee35a1765
# Dropped referenced: 4112bb57ca621b7be08ed7cdb490774f62ffee6c
# Dropped referenced: a680921c7224d086421e34e07196df26195c2dab
# Dropped referenced: 99d5af0a1bd2fa47d2d42aa05391b1774a7879c2
# Dropped referenced: bccf38995692eae3f555e91093e31f9b0199d040
# Dropped referenced: 85b32a283c99e70432ba1db924532ebfc2c941f6
# Dropped referenced: 4e25096408a45a074881a6c10a6e28f42649c273
# Dropped referenced: 6e93c5114c9518d29e28228e17ead4d8353a93c3
# Dropped referenced: 7c3dd8c2d73724a0403ce165872cccc08d5d6e3e
# Dropped referenced: b861991af2f357a7b136fd0b222368d66c41ba94
# Dropped referenced: a377083735d811c2690500f5a038724936bf3b1a
# Dropped referenced: 150558f38704576e5b169247154e87f46eceb0f4
# Dropped referenced: b19d8c6f479580f565ac654aaf7080e185ec7675
# Dropped referenced: 3828b5ac7c4783c5b38cb2adfdf5fe7d76d9a946
# Dropped referenced: 7d3fd645c90f8bd6b6b9c4e43ca70b92c87bc240
# Dropped referenced: 9b964151832af72948e1a69a0be10996634db11d
# Dropped referenced: 42e68745ab69c16e1de544d9b6df92047d38d684
# Dropped referenced: f2bf37eb3a412be57ed7cc3b884d01720c748a07
# Dropped referenced: d22cfbabef1a5abc44a4fe5cd64e1015c05107b1
# Dropped referenced: b8693740ca0e45a21a0728fa19d7dc61d04398d7
# Dropped referenced: 3d7c8891cbfa9a457c24c0cbef25e2c608a951e9
# Dropped referenced: 259d4a9c4bf3906292eecd1a5b62c9160ca5b7a0
# Dropped referenced: 2c37711f78d5d99c2dd1a1a433d7b10155fc141a
# Dropped referenced: 8d46fb7cdeab9be071b0bc134aee5ef942d704b2
# Dropped referenced: c7cc51613320ad93b62d88dd1067fa62945423db
# Dropped referenced: fa33291724d92474e1e73bfa3a61bc123abc4cae
# Dropped referenced: 353053a25d33f3cc80cff63ce56b80aaf25e2d91
# Dropped referenced: 46550847012acfdf81461b17eea58c717e56ddc7
# Dropped referenced: 94a9046d55b848611cadf1063343a7f22f27a3f9
# Dropped referenced: c7ce86819ba09693d23382a9c9e5343bf9c9d68a
# Dropped referenced: 200736c676d9eb6b47ae76fe45af68152aaf6a49
# Dropped referenced: 414e3acbb0a56dc2d90553560b02a16ae8a624ca
# Dropped referenced: 5aec4efe7685f8f7ea151b7d244a26ba5955f003
# Dropped referenced: 9e8cb65b3af0b5da67408fe362a387426b51f5a0
# Dropped referenced: cc085678cae20a3b8b087d144efa4818990a98a7
# Dropped referenced: d8a56b528822db211a5ad6dbe9e7d36fb77e486a
# Dropped referenced: 779cbad5d0a08cd235afc1595fd1e0cf98b470a3
# Dropped referenced: c039adb74f97517e74e53ba7c93806435e5420e2
# Dropped referenced: de367b821d1b7da1e37dd4de74d2bfdb691c461d
# Dropped referenced: 30450ae503822e71404c4d6bfbf1383239eb4b3f
# Dropped referenced: 9cd16cd601646ad529598882ddb076e54ad1c880
# Dropped referenced: 40c4f626a3dc3e2725b39cd404bf9eb02bdbff4c
# Dropped referenced: 43f1d8775ba09eee5f785449597ecc783afde484
# Dropped referenced: 37188c693b7845b43408ed5e26dd13ac90656aca
# Dropped referenced: be7f8f63b541b1a7db405ab3390b24d914fa4376
# Dropped referenced: fb7eaf65e49a2a6bf6fdc11c93aec1b45befafda
# Dropped referenced: 8d225eafd4ed9a293db3606240a6981a57bc0749
# Dropped referenced: a9491ce6127f0f7f0a23efc6ddf9a67a9662027a
# Dropped referenced: 12b9019f99a315a137400389ee7c6faa4cceef35
# Dropped referenced: c0ab916e301fbf1592f16ca07d2f2e426349d41f
# Dropped referenced: 6f6a4d8e60f0982af560c358ad270fdb5dca341a
# Dropped referenced: 641de40b76d76205885c4f6b003ed48d7d400c7c
# Dropped referenced: 5ae34f1ef05fb9bdc511fd7905b5f0fb946867a3
# Dropped referenced: bf25f72eac99111f12409a5472f6ecadee2115f9
# Dropped referenced: 2ebf18e7892e660a833152ddc6cf8f1d21a7b881
# Dropped referenced: c5f002bda80dd14ef5ea0bbb29daae8b403ab066
# Dropped referenced: df7b9d86d85b312ee4159ebc71caedf4a5adc6e9
# Dropped referenced: 767aaacb7940aeb469f32125e39dddca84e1703c
# Dropped referenced: b9392df88f4d47ea88f899e279dad7c6720c229b
# Dropped referenced: 7eeb3c16f3862b3a4fad60005609ec9c0eaa58f2
# Dropped referenced: 7777bf1d7c4f9dd198f020dbd5be9f06f08300de
# Dropped referenced: f5d2b1dbd9dd75b105a58c594622b81cde699617
# Dropped referenced: 09c976cb87c592592abe87f12df2b19850edb728
# Dropped referenced: b16443e4cede82b467e5798917f4f47f8dd993d8
# Dropped referenced: 603474c95a5f1e509211bcdb92c38ac630d44b1a
# Dropped referenced: 09c30074930af2debda418e2f5f7c91a8fce3eab
# Dropped referenced: 8f3e035190b7ca3047d6bab65b51f926cafe3e0d
# Dropped referenced: 5c1f4b02c1f641278fda7db19264dbbaf2c675b4
# Dropped referenced: e5c37be0385b20617d9b0f2cef90a0394cb52e17
# Dropped referenced: 4b30d5aa6b874fe6e0de5e331892df4257dfd5dd
# Dropped referenced: 8bcec017cbc4a935129885de10dbed249f070650
# Dropped referenced: 435ccda1ceb8d3b95e3dc3a745d963fc09847a54
# Dropped referenced: 4f7476037408ac3d993f5088544aab427bc319c1
# Dropped referenced: 3e7bcbc51ef8526892e9b1e578a78bd69aef3491
# Dropped referenced: 98b4d4e24aab57ab4e1124ff8106909050645cfa
# Dropped referenced: 83226bb25557bc39925b37c6350174c5e420e1a6
# Dropped referenced: a7ab38f4814b684b0a9dfeb464c1ba556d0bfc89
# Dropped referenced: 38f362250597ca2dce23b526b802470912b87c36
# Dropped referenced: 971b89da098ba5f583ab0d97338edfbcd41ab7f6
# Dropped referenced: 3ca0b2955c7685376bc61bc0bb538f4ad4e36e1a
# Dropped referenced: 72bb5484b6e38558393607fef984299cb7dbee8e
# Dropped referenced: 52f37706110ad7fd2a05e7dcebb4f09da8ed82ec
# Dropped referenced: 627710def22b525e3e9f878bf1fbe51c579ce099
# Dropped referenced: 3a96fcd5254578215ad00f5aebc7ecdca7632d25
# Dropped referenced: 9150407703013df3591073f905d46d8de0322e5f
# Dropped referenced: fac32066600ae088409d62983d3b2df38f4c57e7
# Dropped referenced: 475ec88b65a8784ca051b76f17ba22b660160464
# Dropped referenced: 313cb12b7dc5b72e56c6e6b1aa8a269e7588392b
# Dropped referenced: 148316b20fabdda8f3d0795c07ebb12986dd59da
# Dropped referenced: ec8e69d5719b9afc8d3e0436ff1876b94fd3e95f
# Dropped referenced: 5ffc5381a3719bbbf9957176a460801338602adf
# Dropped referenced: 2e80ab6a6b6b99c4c45743ee395c50e9bccae038
# Dropped referenced: 4e2f62378c88b4890e0ef18193ba63198bbf34fe
# Dropped referenced: f2c714252bbbcf1010d8490359152f7719862e59
# Dropped referenced: 2b9e16b2fef686e2c5c62d5c3d88d54418ec6472
# Dropped referenced: 2b4ff97f9af9fd078905899a495f0608e88d1b52
# Dropped referenced: 4a8c0050014ceca5dab0542a9974c6d3c2c7373b
# Dropped referenced: d37fc835af4ed081fde386318e5c65eb6b12ddf6
# Dropped referenced: 9d33f95a658bd222505f4722f93cf63262b859a4
# Dropped referenced: e41f7507192e002dbaef66d0c5aeb0db6e945cb5
# Dropped referenced: f12ea2b37862738605236add280919c762aeebcd
# Dropped referenced: 463df6ccdc2eeee9e6c4dadd8a7ec8ff7599df1c
# Dropped referenced: 3f8b789d96f3fc6890e520df116e10d2eac5b74a
# Dropped referenced: 0c85ff92c03dda0385fb43e36131e9f3087eb48a
# Dropped referenced: 826eb83d06ecc1f804f0f9d17d1bb3c8dfa4b8ed
# Dropped referenced: daf6543533e3edb14ad4c6cce7f3e0bfcda22d16
# Dropped referenced: 7c7febd7f96743ff1f8ff51cb8a4e25341ed87a6
# Dropped referenced: b80168f17c2317052b3ec54eb45ee5e941dedd00
# Dropped referenced: 4da751389d8a92be5f7423e746e20008b43cfcd9
# Dropped referenced: 1144c7ee72b81813917ca17092f5ee032c2e7222
# Dropped referenced: 73fab6b34869d65e1a8619998b5090a55848ac52
# Dropped referenced: 602f0d9ea41a469f360fced8e93a93e75fc45cf4
# Dropped referenced: 7ddac859fa9637254074022bfd1daff08dec931d
# Dropped referenced: 45c95bc749496afd1bccb46dd8a67a16aca5f8fa
# Dropped referenced: 9a1f77ddb13e9c632e5bfe6678444f3bd184817f
# Dropped referenced: 3ef9d5e26f31961cadfddafaa30c06a59b138d5a
# Dropped referenced: d4e6caa3b5d6d0349d9d83d02680898cae5a05b5
# Dropped referenced: 9e27e80a700db7bf270f2ea6ef78568e5dee99d1
# Dropped referenced: 67961ea72e01ede3d9f94985468478c1f2e116c4
# Dropped referenced: a5b8a79dc4f442432cfe46f8d74bb2137561f6f0
# Dropped referenced: c31e5f6b13607ac5169d3da2280c75d6c44dab1e
# Dropped referenced: 77629968c7eeb8d6190a404ee6994c0a10b56a71
# Dropped referenced: 7172a547f8b87c680683117df3cd1d609321a6f6
# Dropped referenced: 29debe35fb6cbe3cdede9a6f0e993681874bc8ec
# Dropped referenced: 086d24b8d958e1fd74706beb69ed8d4f9df89130
# Dropped referenced: 09934885464d3425e83b46f7c71caac2c52e84fd
# Dropped referenced: 43816ae938e35583a5965410e40af00334865425
# Dropped referenced: 5d20697d2575ff27c910fedc8f078dcce7c8cf2b
# Dropped referenced: 89b916ec4bc427dd47314481c863c98a4339a6fc
# Dropped referenced: 14960dc80882e1b6bfb7cc67ccdd94c78a47c08b
# Dropped referenced: 719efee6b694d6f203a005fa049f2fb266212a0c
# Dropped referenced: 4725fe2ecf83431a7a4aa22b4b3e3280b88d8fd6
# Dropped referenced: d93a0cfaaf8bf6580f44687f15bbac704ed2d51e
# Dropped referenced: 2265a198e55665ed3df0f19688350567dab593de
# Dropped referenced: 7e67efa5f49ab53a7554b69f6fab9f7dd03f6b8f
# Dropped referenced: 78b251665eb80ae9a35768ec00ad0d9c34556304
# Dropped referenced: 5d268d9ec34d6dc5718b193edb01a49ab47b2b26
# Dropped referenced: 4e0eaa380d0fbfb0e629bd27696aeea7cb48a3c9
# Dropped referenced: 9f7d9abb2277e924a291033d5c3d1195989e80ff
# Dropped referenced: e2f4f64a17a05379e45f713d10d7c546bda7734a
# Dropped referenced: 884b6101e7ae7ac3c92a1d218644f9084c67792d
# Dropped referenced: 4d6e34a19d852d9322a8f1674e46838ec9335a36
# Dropped referenced: ca10ca7166d9fc5af99b7442bbe5456909f80867
# Dropped referenced: 4450c3a8629e4b8094af24ece1e876a40eb9de13
# Dropped referenced: 6bb2917ea86c89be66679cbef06570756ea19d71
# Dropped referenced: 1aa00fc3819266a2a0f6d038b008ee2731b54d08
# Dropped referenced: 5d17e61595ecf88dceae1c7ca74ca8a9e40fdb78
# Dropped referenced: 438de2456449dc22c3cf2e16fe4dc29368fd0ba0
# Dropped referenced: 463df6ccdc2eeee9e6c4dadd8a7ec8ff7599df1c
# Dropped referenced: ea6caf15359fe949f4d80dbdfed0da7fe4b955d3
# Dropped referenced: 0bf1391ce8f1311c1237d350fac305b0895f9f67
# Dropped referenced: 71249482341f5de2d6bdceca4a8bd6eba66800f7
# Dropped referenced: ee3b632fcb64928d5b12d48a04731e8cd39dcced
# Dropped referenced: 59e499de9bf4bb3076c202a2c79f957cacb5be5f
# Dropped referenced: bb70cf5840298b9821d8b6c3838af27c1d5f4524
# Dropped referenced: 0fb14c68d32fd675b226510de2bef780e341f0b2
# Dropped referenced: de161a9d1e604d922db70cea3a80508d760bee5b
# Dropped referenced: e3fd96eb310257cf193fbf1a7a393dba8bfbeba5
# Dropped referenced: f5c73b1abf9201af0abf6da873f671c95aa5ce5c
# Dropped referenced: 43816ae938e35583a5965410e40af00334865425
# Dropped referenced: 5d20697d2575ff27c910fedc8f078dcce7c8cf2b
# Dropped referenced: 609b8ab94ae9554bad3684c76919217674b3683a
# Dropped referenced: b8ec37aba9691996387a98ab66f863a7f4595c31
# Dropped referenced: ccb5eb4c222e396e738e772f93f97b0c2147af49
# Dropped referenced: fcc39e63a8e135272818c5d9a5b3cc0d8013f044
# Dropped referenced: 4b0cb61f04bd3f56eb57e2110ee0493c716d50f3
# Dropped referenced: 15975b59e7a581fed2aa8449ee55cc381fb7953e
# Dropped referenced: fd2978436a8350c9a6cd7e0076c5cf4164ac6f2f
# Dropped referenced: d53853efe479bdba09bd97f697bdb8bd52bf4d83
# Dropped referenced: 43c39c88c8a3ca1e8a108f2a6c5712106ff9cd4a
# Dropped referenced: 68bd22075e870381e861d39cc6d629b3fd03c953
# Dropped referenced: a0b180cda753cf6e2c490762d1c3c9602fa42069
# Dropped referenced: ea69ba4deca1c7d10544f164dcc84156d23319a3
# Dropped referenced: c1182803344877ec1793a34fe19089d71d68bc8d
# Dropped referenced: e3044437b9b45012bc79ce1d926b532d998c2d9d
# Dropped referenced: d52f0366af7f69956d14cd4988299bea22b9200b
# Dropped referenced: 2f7652fd2c7a073f9f36751d2090ae49fbdea7f8
# Dropped referenced: c14c2c9e907c4c934a76a2d1bffc21fa0641d7c5
# Dropped referenced: 83226bb25557bc39925b37c6350174c5e420e1a6
# Dropped referenced: 089a96db127d062e1d80234977a0b53b19e88011
# Dropped referenced: 188022ac15cc7e9d375b5b019af8c6ff119f80a8
# Dropped referenced: 77f83e84cdd974bea6b96543e9a383f91a860286
# Dropped referenced: b2bfa70f16ea36666756a6d0d0b7c957d8b92edb
# Dropped referenced: b4b949fa7425fa78c360c0efe0a7cff33588228f
# Dropped referenced: f74653aa213f9efd852c6167ee09ecf5a28206da
# Dropped referenced: 9c930e3b0978f75f7ac13730778265d62ad2be58
# Dropped referenced: ebff42a6c52b6117e0cd8d241aa8d961a889265a
# Dropped referenced: 43f1d8775ba09eee5f785449597ecc783afde484
# Dropped referenced: be7f8f63b541b1a7db405ab3390b24d914fa4376
# Dropped referenced: e2fa49d57c46b076c4b9554ec775c2bbbf397716
# Dropped referenced: 45c95bc749496afd1bccb46dd8a67a16aca5f8fa
# Dropped referenced: ed816dd3a03fca11263ae71d44f7aee4bfdedf36
# Dropped referenced: ed9133009dd451bd64215cca7deba6e0b8d7c7b1
# Dropped referenced: 6068f1552b176d5b1fbff07596e8fb6020c4fc89
# Dropped referenced: 929e377e579c65fe46d405b151bfde005d9a46b1
# Dropped referenced: ceae5f672f0adcf13ec0a4b9efffe41f3cb25f86
# Dropped referenced: ab951f4b7b715a4e381f5241388e372a2ab24698
# Dropped referenced: 2ebf18e7892e660a833152ddc6cf8f1d21a7b881
# Dropped referenced: 49e21b17863e7117338298fe8d14a34a9c3a945b
# Dropped referenced: 767aaacb7940aeb469f32125e39dddca84e1703c
# Dropped referenced: 76304888f2fb125b3f19f4af1cef0750b7d19ecb
# Dropped referenced: db52120c4cefe8dae1a9f5a90eb211554908ce38
# Dropped referenced: 9c366788e06ae2d60c9958b99bdd110f4cfa8c59
# Dropped referenced: f5d2b1dbd9dd75b105a58c594622b81cde699617
# Dropped referenced: 733d455f690f5a7361ee010657ec1adad6dde28f
# Dropped referenced: 09c976cb87c592592abe87f12df2b19850edb728
# Dropped referenced: 89b916ec4bc427dd47314481c863c98a4339a6fc
# Dropped referenced: 362ce17b51b28f129d03047a2d57bd460f5fe18a
# Dropped referenced: 69f6963992e7b82f6c58855af35d661e3fea6036
# Dropped referenced: 27f1b54ee5c8e6afe0398486b2dcd1e1d779d76e
# Dropped referenced: 98adf59144fcad0412081c4a9c0130bd8ef9dacb
# Dropped referenced: 08ca03740c6c4137749bb46589da375f2475450f
# Dropped referenced: e224a36551d57cda0cae331e5eb8feb81e4328f2
# Dropped referenced: 374cd3fa43064deaca9b9790d0746b4b2a18a937
# Dropped referenced: 3a618c6e8fec20c578e402cd1af3400a73e77d35
# Dropped referenced: 2f8076fc67dc88bb34df176b1e01d7482cc8a782
# Dropped referenced: 37b187e3df04fe7dd31293222407b4b86f3089fb
# Dropped referenced: 91d9bb61102f3d9fe63fe4c82cc9bf112c3d0b4e
# Dropped referenced: cc031b2edacd3a16b5eccafa815def7e732aa757
# Dropped referenced: 47f19ef121d2606461b626bb6767effa154c5961
# Dropped referenced: fc97746398a562bd40729cd6110dc9e70a6e5d36
# Dropped referenced: 8e7d38bed1ad912a11f0c8faf6fdd6107db6cdfd
# Dropped referenced: 50cd23b374a0480044bf78939588cb3c7b58fcde
# Dropped referenced: 9771e20ec185250e5135e05d5f96e107e6f7d6a4
# Dropped referenced: 822cb9c6077a23dfacb837f6169a07cbd4fae9fc
# Dropped referenced: 1370419225c287cce627653aa090177ba90fc4c4
# Dropped referenced: 2770de32287b1ad48e2bc4227666a26231ceb7d3
# Dropped referenced: bccf38995692eae3f555e91093e31f9b0199d040
# Dropped referenced: 35e7439ae9218549c3ee604d77111d7463d3cffb
# Dropped referenced: f5de8face8ae71a5279342d6997bac8cbdba9ba7
# Dropped referenced: aa3245ee87573ec7fc8fed1e9d70b3a3305062d2
# Dropped referenced: 43230fe1572ed9ffe2e29dc6c2f3a798696d1afd
# Dropped referenced: 9b2cec3acc51a72de35b38a14fd4dbe586193286
# Dropped referenced: a21ba9979c3304c9662ca85c6f168661cad8d17c
# Dropped referenced: 7fb7dc93ecd911b8254b9f08a8425aa250a1a662
# Dropped referenced: fdb6d1e742de98f261174d6bec171f3bbfe87446
# Dropped referenced: 5dbc7c61d3dd0c50cdfc2fb2415e0a0989dd0dd5
# Dropped referenced: 3184c5f9125917590aef3fcb4b0084ae1c6efb71

# %% [markdown]
# Now that we have the data, let's format it as a network with appropriate node attributes.

# %%
import networkx as nx
import textwrap

G = nx.from_pandas_edgelist(edges,
                            source = 'referencing',
                            target = 'referenced',
                            create_using = nx.Graph())

# Label nodes by name
node_label = dict()
for i in nodes:
    title = nodes[i][0]
    year = str(round(nodes[i][2]))
    if 'name' in nodes[i][3]:
        journal = nodes[i][3]['name']
    else:
        journal = "Unknown Journal"
    if len(nodes[i][4]) == 0:
        authors = "Unknown Authors"
    elif len(nodes[i][4]) == 1:
        authors = nodes[i][4][0]['name'].split()[-1]
    elif len(nodes[i][4]) == 2:
        authors = nodes[i][4][0]['name'].split()[-1]+" & "+nodes[i][4][1]['name'].split()[-1]
    else:
        authors = nodes[i][4][0]['name'].split()[-1]+" et al."
    node_label[i] = authors+", "+year+"\n"+textwrap.fill(title, 25)
    
nx.set_node_attributes(G, node_label, 'label')
    
# Define node level as publication date
node_level = dict()
for i in nodes:
    node_level[i] = nodes[i][1].timestamp()/31536000

nx.set_node_attributes(G, node_level, 'level')

# Vary node size by number of citations (except source node)
node_citations = (edges.loc[:,'referenced'].value_counts()*5).to_dict()
node_citations[edges.iloc[0,0]] = 50
nx.set_node_attributes(G, node_citations, 'size')

# Vary node color by seed/parent/grandparent
node_color = dict()
for i in nodes:
    if i == edges.iloc[0,0]:
        node_color[i] = "#A5243D"
    elif i in direct_refs:
        node_color[i] = "#B48291"
    else:
        node_color[i] = "#AFAAB9"

nx.set_node_attributes(G, node_color, 'color')

# %% [markdown]
# Now time to visualize!

# %%
from pyvis.network import Network

net = Network(bgcolor = '#222222', 
              font_color = 'white', 
              layout = True, 
              directed = False,
              heading = "<b>Provenance of Kessler &amp; Oberauer, 2018</b><br>Red nodes are direct references of the seed paper, while grey nodes are references of references. All second-order references with fewer than two connections have been removed to avoid clutter.")

net.from_nx(G)

# Set appropriate options
net.set_options("""
const options = {
  "nodes": {
    "borderWidthSelected": 3,
    "opacity": 0.8,
    "font": {
      "size": 12
    },
    "size": null
  },
  "edges": {
    "color": {
      "opacity": 0.5
    },
    "hoverWidth": 5,
    "scaling": {
      "max": 25
    },
    "selectionWidth": 5,
    "selfReferenceSize": null,
    "selfReference": {
      "angle": 0.7853981633974483
    },
    "smooth": false,
    "width": 5
  },
  "layout": {
    "hierarchical": {
      "enabled": true,
      "levelSeparation": 50,
      "direction": "LR"
    }
  },
  "interaction": {
    "hover": true
  },
  "physics": {
    "hierarchicalRepulsion": {
      "centralGravity": 1.55,
      "springLength": 150,
      "springConstant": 0.2,
      "nodeDistance": 200,
      "avoidOverlap": null
    },
    "minVelocity": 0.75,
    "solver": "hierarchicalRepulsion"
  }
}
""")

net.show('name.html')
